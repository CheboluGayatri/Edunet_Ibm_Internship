# %% [markdown]
# <a href="https://colab.research.google.com/github/CheboluGayatri/Edunet_Ibm_Internship/blob/main/IBM_WEEK1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Introduction to Artificial Intelligence**
#
# **Objectives**
#
#  => 1. AI in Everyday Life
#
#  =>2.Artificial Intelligence
#
#  =>3.History
#
#  =>4.Application of AI
#
#  =>5.Job Roles in AI
#
#  =>6.Machine Learning
#
#  =>7.Working Mechanism

# %% [markdown]
# **Where do you see AI in everyday Life**
#
# =>mobile applications that which we use cnn that used to classify faces and detect facail recognition
#
# =>Google maps that is used to detect location and capture satelite and shows location traffic also
#
# =>spotify it is used to convert normal device into smart that able think like human suggest music and generate music generation based on user

# %% [markdown]
# **Artificial Intelligence**
#
# Artificial intelligence(AI)is a field of computer science that refers to the development of computer systems that can perform tasks that typically require human intelligence
#
# =>Ai systems are designed  to perform task such as
#
# Problem solving: Google Maps finding the best route
#
# 2. Learning from data: Spotify recommending songs
#
# 3. Making decisions :Email spam filter deciding whether an email is spam or not

# %% [markdown]
# **Traditional Programming**
#
# =>fallows predifiend rules
#
# =>output is predictable
#
# =>example: calculator
#
# **AI**
#
# => Learns patterns from data
#
# =>output is adaptive
#
# =>chatbot

# %% [markdown]
# **Evaluation of AI**
#
# 1950=Turing Test
#
# 1956=dartmouth conference
#
# 1997=Deep Blue  beats Kasparav
#
# 1980=Expert systems
#
# 2012=Deep Learing(Alex Net)
#
# 2020=gpt3
#
# 2023=chatgpt and
#
# 2025=multimodel

# %% [markdown]
# **Applications**
# 1.Education
#
# 2.Healthcare
#
# 3.finance
#
# 4.Entertainment meadia
#
# 5.Cybersecurity
#
# 6.content creation
#
# 7.Gaming
#
# 8.Virtual asissistant

# %% [markdown]
# **Artificial intelligence**
#
# AI refers to the development of computer systems to perform tasks that need human intelligence
#
# **Machine Learing**
#
# Machine Learing is a subset of AI that enables computers to learn from experience
#
# **Deep Learing**
#
# Deep Learing is a Subset of ML that uses neural networks for data processing
#
# **Geneartive AI**
#
# Generative AI is a subset of DL that generates content like text,images, or code based on input
